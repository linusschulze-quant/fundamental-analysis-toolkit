# %% [markdown]
# # Profitability Analysis
#
# This notebook evaluates the company's profitability, margins, returns, and
# valuation metrics to assess business quality and earnings power.

# %%
from src.setup import *

# %% [markdown]
# ## Step 1: Metric Categories
#
# We compute the following groups of metrics:
#
# - **Valuation**: P/E, Earnings Yield, PEG
# - **Margins**: Gross, Net, EBIT, EBITDA
# - **Returns**: ROE, ROA, ROIC
# - **Cash Flow**: Free Cash Flow Yield, Operating Leverage
# - **Growth**: EPS Growth, Free Cash Flow Growth

# %%
def profitability_analysis(
    annual_data,
    income_statement,
    balance_sheet,
    market_cap,
    price,
    tax_rate,
    free_cashflow,
    eps,
    price_date,
):
    """
    Compute profitability, margin, return and valuation metrics.

    Parameters:
    ----------
    annual_data : pandas.DataFrame
        Historical annual flow and valuation time series.
    income_statement : pandas.DataFrame
        Annual income statement snapshot.
    balance_sheet : pandas.DataFrame
        Annual balance sheet snapshot.
    market_cap : float
        Market capitalization as of the stored market snapshot date.
    price : float
        Share price as of the stored market snapshot date.
    tax_rate : float
        Corporate tax rate as a decimal.
    free_cashflow : float
        Trailing-twelve-month free cash flow.
    eps : float
        Trailing-twelve-month earnings per share.
    price_date : pandas.Timestamp
        Date of the stored market snapshot.

    Returns
    -------
    pd.DataFrame
        Key profitability and valuation metrics.
    """

    # --- Core financials ---
    revenue = income_statement.loc["TotalRevenue"].iloc[0]
    gross_profit = income_statement.loc["GrossProfit"].iloc[0]
    net_income = income_statement.loc["NetIncome"].iloc[0]
    ebit = income_statement.loc["EBIT"].iloc[0]
    ebitda = income_statement.loc["EBITDA"].iloc[0]

    equity = balance_sheet.loc["StockholdersEquity"].iloc[0]
    debt = balance_sheet.loc["TotalDebt"].iloc[0]
    cash = balance_sheet.loc["CashAndCashEquivalents"].iloc[0]
    total_assets = balance_sheet.loc["TotalAssets"].iloc[0]

    assets_previous = balance_sheet.loc["TotalAssets"].iloc[1]
    equity_previous = balance_sheet.loc["StockholdersEquity"].iloc[1]
    average_assets = (total_assets + assets_previous) / 2
    average_equity = (equity + equity_previous) / 2

    # --- Valuation ---
    pe_ratio = price / eps if eps != 0 else np.nan 
    earnings_yield = eps / price if price != 0 else np.nan

    # --- Margins ---
    gross_margin = gross_profit / revenue if revenue != 0 else np.nan
    net_margin = net_income / revenue if revenue != 0 else np.nan
    ebit_margin = ebit / revenue if revenue != 0 else np.nan
    ebitda_margin = ebitda / revenue if revenue != 0 else np.nan

    # --- Returns ---
    nopat = ebit * (1 - tax_rate)
    invested_capital = equity + debt - cash

    roe = net_income / average_equity if average_equity != 0 else np.nan
    roa = net_income / average_assets if average_assets != 0 else np.nan
    roic = nopat / invested_capital if invested_capital != 0 else np.nan

    # --- Cashflow metrics ---
    fcf_yield = free_cashflow / market_cap if market_cap != 0 else np.nan
    revenue_previous = income_statement.loc["TotalRevenue"].iloc[1]
    ebit_previous = income_statement.loc["EBIT"].iloc[1]
    revenue_growth = revenue / revenue_previous - 1 if revenue_previous != 0 else np.nan
    ebit_growth = ebit / ebit_previous - 1 if ebit_previous != 0 else np.nan
    operating_leverage = (
        ebit_growth / revenue_growth
        if not pd.isna(revenue_growth)
        and not np.isclose(revenue_growth, 0.0, atol=1e-12)
        else np.nan
    )

    # --- EPS growth (trailing) ---
    eps_series = annual_data[f"{TICKER}: Annual EPS"].dropna()

    trailing_growth = np.nan
    trailing_peg = np.nan
    if len(eps_series) >= 4:
        growth_rates = [
            eps_series.iloc[-1] / eps_series.iloc[-2] - 1,
            eps_series.iloc[-2] / eps_series.iloc[-3] - 1,
            eps_series.iloc[-3] / eps_series.iloc[-4] - 1,
        ]
        trailing_growth = np.mean(growth_rates)
        trailing_peg = pe_ratio / (trailing_growth * 100) if trailing_growth > 0 else np.nan

    # --- Free Cashflow Growth ---
    fcf_growth = np.nan
    fcf_series = annual_data[
        f"{TICKER}: Annual Free Cash Flow"
    ].dropna()
    if len(fcf_series) >= 2:
        prev_fcf = fcf_series.iloc[-2]
        fcf_growth = (fcf_series.iloc[-1] / prev_fcf - 1) if prev_fcf != 0 else np.nan


    # --- Output ---
    metrics = {
        "EPS (TTM)": eps,
        f"P/E as of {pd.Timestamp(price_date).date()}": pe_ratio,
        "Earnings Yield": earnings_yield,
        "Gross Margin": gross_margin,
        "Net Margin": net_margin,
        "EBIT Margin": ebit_margin,
        "EBITDA Margin": ebitda_margin,
        "Free Cash Flow Yield (TTM)": fcf_yield,
        "Degree of Operating Leverage (FY2025 vs FY2024)": operating_leverage,
        "Return on Equity (average annual equity)": roe,
        "Return on Assets (average annual assets)": roa,
        "Simplified ROIC": roic,
        "Trailing PEG Ratio": trailing_peg,
        "Average EPS Growth (3 Years)": trailing_growth,
        "Historical Annual FCF Growth (Latest YoY)": fcf_growth,
        "Free Cash Flow (TTM)": free_cashflow,
        "Total Assets": total_assets,
        "Average Total Assets": average_assets,
        "Average Stockholders' Equity": average_equity,
        "Revenue": revenue,
        "Net Income": net_income,
        "EBIT": ebit,
        "EBITDA": ebitda
    }
     
    df_metrics = pd.DataFrame.from_dict(metrics, orient="index", columns=["Value"])
    return df_metrics

# %% [markdown]
# ## Step 2: Run Profitability Analysis
#
# We now compute all profitability and valuation metrics using the latest financial data.

# %%
df_profit = profitability_analysis(
    annual_data=annual_data,
    income_statement=income_statement,
    balance_sheet=balance_sheet,
    market_cap=market_cap,
    price=price,
    tax_rate=TAX_RATE,
    free_cashflow=ttm_fcf,
    eps=ttm_eps,
    price_date=price_date,
)

# %% [markdown]
# ## Step 3: Results
#
# The table below summarizes the company's profitability, returns, margins, and valuation metrics.

# %%
with pd.option_context("display.float_format", "{:,.2f}".format):
    display(df_profit)
# Out:
#                                                              Value
# EPS (TTM)                                                    14.06
# P/E as of 2025-12-26                                         34.70
# Earnings Yield                                                0.03
# Gross Margin                                                  0.69
# Net Margin                                                    0.36
# EBIT Margin                                                   0.45
# EBITDA Margin                                                 0.55
# Free Cash Flow Yield (TTM)                                    0.02
# Degree of Operating Leverage (FY2025 vs FY2024)               0.92
# Return on Equity (average annual equity)                      0.33
# Return on Assets (average annual assets)                      0.18
# Simplified ROIC                                               0.27
# Trailing PEG Ratio                                            3.37
# ...
