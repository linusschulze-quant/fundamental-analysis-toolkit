# %% [markdown]
# # Beneish M-Score Analysis
#
# This notebook calculates the Beneish M-Score to assess the likelihood of earnings manipulation
# based on financial statement indicators.

# %%
from src.setup import *

# %% [markdown]
# ## What is the Beneish M-Score?
#
# The Beneish M-Score is a forensic screening model that combines eight financial ratios.
# It provides an indication, not proof, of possible earnings manipulation.
#
# Interpretation:
# - **M-Score below -2.22**: lower indication under the model
# - **M-Score at or above -2.22**: potential warning signal requiring further analysis

# %% [markdown]
# ## Indicators Used
#
# 1. DSRI — Days Sales in Receivables Index
# 2. GMI — Gross Margin Index
# 3. SGI — Sales Growth Index
# 4. AQI — Asset Quality Index
# 5. DEPI — Depreciation Index
# 6. SGAI — SG&A Expense Index
# 7. TATA — Total Accruals to Total Assets
# 8. LVGI — Leverage Index

# %%
def calculate_beneish_m_score(
    income_statement,
    balance_sheet,
    cash_flow,
):
    """
    Calculate the Beneish M-Score to detect potential earnings manipulation.

    Parameters
    ----------
    income_statement : pandas.DataFrame
        Annual income statement snapshot.
    balance_sheet : pandas.DataFrame
        Annual balance sheet snapshot.
    cash_flow : pandas.DataFrame
        Annual cash flow snapshot.

    Returns
    -------
    pandas.Series
        Numeric Beneish components and final M-Score.
    """
    
    required_rows = {
        "income_statement": (
            income_statement,
            ["TotalRevenue", "GrossProfit", "SellingGeneralAndAdministration", "NetIncome"],
        ),
        "balance_sheet": (
            balance_sheet,
            [
                "AccountsReceivable",
                "CurrentAssets",
                "NetPPE",
                "TotalAssets",
                "LongTermDebt",
                "CurrentLiabilities",
            ],
        ),
        "cash_flow": (cash_flow, ["OperatingCashFlow", "Depreciation"]),
    }

    for statement_name, (statement, rows) in required_rows.items():
        missing_rows = [row for row in rows if row not in statement.index]
        if missing_rows:
            raise KeyError(f"Missing rows in {statement_name}: {missing_rows}")

    common_periods = sorted(
        set(income_statement.columns)
        & set(balance_sheet.columns)
        & set(cash_flow.columns),
        reverse=True,
    )
    if len(common_periods) < 2:
        raise ValueError("At least two aligned annual statement periods are required.")

    t, t1 = common_periods[:2]
    revenue_t = income_statement.loc["TotalRevenue", t]
    revenue_t1 = income_statement.loc["TotalRevenue", t1]
    ar_t = balance_sheet.loc["AccountsReceivable", t]
    ar_t1 = balance_sheet.loc["AccountsReceivable", t1]
    dsri = (ar_t / revenue_t) / (ar_t1 / revenue_t1)

    gross_margin_t = income_statement.loc["GrossProfit", t] / revenue_t
    gross_margin_t1 = income_statement.loc["GrossProfit", t1] / revenue_t1
    gmi = gross_margin_t1 / gross_margin_t
    sgi = revenue_t / revenue_t1

    current_assets_t = balance_sheet.loc["CurrentAssets", t]
    current_assets_t1 = balance_sheet.loc["CurrentAssets", t1]
    ppe_t = balance_sheet.loc["NetPPE", t]
    ppe_t1 = balance_sheet.loc["NetPPE", t1]
    total_assets_t = balance_sheet.loc["TotalAssets", t]
    total_assets_t1 = balance_sheet.loc["TotalAssets", t1]
    asset_quality_t = 1 - (current_assets_t + ppe_t) / total_assets_t
    asset_quality_t1 = 1 - (current_assets_t1 + ppe_t1) / total_assets_t1
    aqi = asset_quality_t / asset_quality_t1

    depreciation_t = cash_flow.loc["Depreciation", t]
    depreciation_t1 = cash_flow.loc["Depreciation", t1]
    depreciation_rate_t = depreciation_t / (depreciation_t + ppe_t)
    depreciation_rate_t1 = depreciation_t1 / (depreciation_t1 + ppe_t1)
    depi = depreciation_rate_t1 / depreciation_rate_t

    sga_t = income_statement.loc["SellingGeneralAndAdministration", t]
    sga_t1 = income_statement.loc["SellingGeneralAndAdministration", t1]
    sgai = (sga_t / revenue_t) / (sga_t1 / revenue_t1)

    net_income_t = income_statement.loc["NetIncome", t]
    operating_cash_flow_t = cash_flow.loc["OperatingCashFlow", t]
    tata = (net_income_t - operating_cash_flow_t) / total_assets_t

    leverage_t = (
        balance_sheet.loc["LongTermDebt", t]
        + balance_sheet.loc["CurrentLiabilities", t]
    ) / total_assets_t
    leverage_t1 = (
        balance_sheet.loc["LongTermDebt", t1]
        + balance_sheet.loc["CurrentLiabilities", t1]
    ) / total_assets_t1
    lvgi = leverage_t / leverage_t1

    # --- Beneish M-Score calculation ---
    m_score = (
        -4.84
        + 0.92 * dsri
        + 0.528 * gmi
        + 0.404 * aqi
        + 0.892 * sgi
        + 0.115 * depi
        - 0.172 * sgai
        + 4.679 * tata
        - 0.327 * lvgi
    )

    return pd.Series(
        {
            "DSRI": dsri,
            "GMI": gmi,
            "AQI": aqi,
            "SGI": sgi,
            "DEPI": depi,
            "SGAI": sgai,
            "LVGI": lvgi,
            "TATA": tata,
            "M-Score": m_score,
        },
        name="Value",
        dtype=float,
    )

# %% [markdown]
# ## Step 1: Calculate the Beneish M-Score

# %%
beneish_results = calculate_beneish_m_score(
    income_statement=income_statement,
    balance_sheet=balance_sheet,
    cash_flow=cash_flow,
)
m_score = beneish_results["M-Score"]

# %% [markdown]
# ## Step 2: Interpret Results

# %%
with pd.option_context("display.float_format", "{:.3f}".format):
    display(beneish_results.to_frame())

if m_score < -2.22:
    interpretation = (
        "Lower indication of earnings manipulation according to the Beneish model."
    )
else:
    interpretation = (
        "Potential warning signal; this is not proof of earnings manipulation."
    )

print(f"Annual periods compared: {income_statement.columns[0].date()} and {income_statement.columns[1].date()}")
print(f"M-Score: {m_score:.3f}")
print(interpretation)
# Out:
#          Value
# DSRI     1.068
# GMI      1.014
# AQI      0.828
# SGI      1.149
# DEPI     1.052
# SGAI     0.892
# LVGI     0.893
# TATA    -0.055
# M-Score -2.546
# Annual periods compared: 2025-06-30 and 2024-06-30
# M-Score: -2.546
# Lower indication of earnings manipulation according to the Beneish model.
