# %% [markdown]
# # Risk/Reward Analysis
#
# This notebook evaluates valuation-based risk/reward using stored historical EV/EBITDA
# and P/E series. It combines WC/Buy/FV/Sell scenarios, neutral quantile references,
# direct empirical frequencies, and full historical histograms.

# %%
from src.setup import *

# %% [markdown]
# ## Methodology and data periods
#
# ### WC / Buy / FV / Sell
#
# - WC combines the historical minimum with the average of the next three low observations.
# - Buy is the average of those three low reference observations.
# - Sell is the average of three high reference observations.
# - FV is the midpoint between Buy and Sell.
# - Risk/reward compares the share price as of 2025-12-26 with WC and Sell implied prices.
# - WC/Buy/FV/Sell levels use annual-average valuation references to reduce the
# influence of short-term extremes, while quantiles, frequencies, and histograms
# use the full historical valuation series.
#
# ### Quantile analysis
#
# Q10, Q25, Q50, Q75, and Q90 are neutral statistical references. They complement
# and do not replace the separate WC/Buy/FV/Sell scenario system.
#
# ### Historical frequencies
#
# Direct empirical frequencies compare the stored observations with the multiple as of
# 2025-12-26. They are descriptive sample statistics, not forecast probabilities.

# %% [markdown]
# ## Step 1: Define valuation and risk/reward functions

# %%
def clean_historical_series(historical_series):
    """Return a numeric, non-missing historical valuation series."""
    series = pd.to_numeric(historical_series, errors="coerce").dropna()
    if series.empty:
        raise ValueError("Historical valuation series is empty.")
    return series.astype(float)


def valuation_quantiles(historical_series):
    """Return neutral Q10, Q25, Q50, Q75, and Q90 references."""
    series = clean_historical_series(historical_series)
    quantiles = series.quantile([0.10, 0.25, 0.50, 0.75, 0.90])
    quantiles.index = [
        "Q10 Lower Quantile",
        "Q25",
        "Q50 Median",
        "Q75",
        "Q90 Upper Quantile",
    ]
    return quantiles.astype(float)


def wc_buy_fv_sell_levels(historical_series):
    """Calculate WC, Buy, FV, and Sell multiples from sorted observations."""
    values_sorted = sorted(clean_historical_series(historical_series).tolist())
    if len(values_sorted) < 4:
        raise ValueError("At least four historical observations are required.")

    wc = round((values_sorted[0] + np.mean(values_sorted[1:4])) / 2)
    buy = np.mean(values_sorted[1:4])
    sell = np.mean(values_sorted[-4:-1])
    fair_value = (buy + sell) / 2

    return pd.Series(
        {"WC": wc, "Buy": buy, "FV": fair_value, "Sell": sell},
        dtype=float,
    )


def prices_from_multiples(
    multiples, metric, ebitda, net_debt, eps, shares_outstanding
):
    """Translate numeric valuation multiples into per-share prices."""
    if shares_outstanding == 0:
        raise ValueError("Shares outstanding must be non-zero.")

    if metric == "EV/EBITDA":
        prices = (ebitda * multiples - net_debt) / shares_outstanding
    elif metric == "P/E":
        prices = eps * multiples
    else:
        raise ValueError(f"Unsupported valuation metric: {metric}")

    return prices.astype(float)


def historical_frequency(historical_series, current_multiple):
    """Return direct empirical frequencies around a point-in-time multiple."""
    series = clean_historical_series(historical_series)
    if pd.isna(current_multiple):
        raise ValueError("Point-in-time valuation multiple is missing.")

    frequency_above = (series > current_multiple).mean()
    frequency_at_or_below = (series <= current_multiple).mean()
    if not np.isclose(frequency_above + frequency_at_or_below, 1.0):
        raise ValueError("Historical frequency partition does not sum to 1.0.")

    return pd.Series(
        {
            "Historical Frequency Above Current Multiple": frequency_above,
            "Historical Frequency At or Below Current Multiple": frequency_at_or_below,
        },
        dtype=float,
    )


def histogram_table(historical_series, bins=15):
    """Create a complete descriptive histogram table."""
    series = clean_historical_series(historical_series)
    if bins <= 0:
        raise ValueError("Number of histogram bins must be positive.")

    counts, edges = np.histogram(series, bins=bins)
    histogram = pd.DataFrame(
        {
            "Low": edges[:-1],
            "High": edges[1:],
            "Number of Observations": counts,
        }
    )
    histogram["% of Observations"] = counts / len(series) * 100
    histogram["Cumulative (%)"] = histogram["% of Observations"].cumsum()
    histogram["Historical Frequency Above Bin (%)"] = (
        100 - histogram["Cumulative (%)"]
    )
    return histogram


def calculate_risk_reward(price, wc_price, sell_price):
    """Calculate chance, risk, and their ratio from WC and Sell prices."""
    if wc_price < price and sell_price < price:
        chance = 0.0
        risk = price - wc_price
        ratio = 0.0
    elif wc_price > price and sell_price > price:
        chance = sell_price - price
        risk = 0.0
        ratio = np.inf
    else:
        chance = sell_price - price
        risk = price - wc_price
        ratio = chance / risk if risk != 0 else np.inf

    return pd.Series(
        {"Chance": chance, "Risk": risk, "Risk/Reward Ratio": ratio},
        dtype=float,
    )

# %% [markdown]
# ## Step 2: Prepare stored snapshot inputs

# %%
eps = ttm_eps
ebitda = income_statement.loc["EBITDA"].iloc[0]

total_debt = quarterly_balance_sheet.loc["TotalDebt"].iloc[0]
cash = quarterly_balance_sheet.loc["CashAndCashEquivalents"].iloc[0]
net_debt = total_debt - cash


# =========================
# Annual Reference Series
# =========================
# Used for the WC / Buy / FV / Sell system.

ev_reference_series = (
    annual_data[
        f"{TICKER}: EV/EBITDA"
    ]
    .dropna()
)

pe_reference_series = (
    annual_data[
        f"{TICKER}: PE Ratio"
    ]
    .dropna()
)


# =========================
# Full Historical Series
# =========================
# Used for quantiles, historical frequencies,
# and histogram analysis.

ev_series = (
    df_raw[
        f"{TICKER}: EV/EBITDA"
    ]
    .dropna()
)

pe_series = (
    df_raw[
        f"{TICKER}: PE Ratio"
    ]
    .dropna()
)


# =========================
# Point-in-Time Multiples
# =========================

current_ev_ebitda = latest_ev_ebitda
current_pe = latest_pe

# =========================
# Validation
# =========================

if pd.isna(eps):
    raise ValueError(
        "TTM EPS is unavailable in the stored raw data."
    )

if pd.isna(ebitda):
    raise ValueError(
        "FY2025 EBITDA is unavailable in the annual snapshot."
    )

# %% [markdown]
# ## Step 3: Calculate scenarios, quantiles, frequencies, and histograms

# %%
ev_wc_levels = wc_buy_fv_sell_levels(
    ev_reference_series
)

pe_wc_levels = wc_buy_fv_sell_levels(
    pe_reference_series
)
ev_wc_prices = prices_from_multiples(
    ev_wc_levels, "EV/EBITDA", ebitda, net_debt, eps, shares_outstanding
)
pe_wc_prices = prices_from_multiples(
    pe_wc_levels, "P/E", ebitda, net_debt, eps, shares_outstanding
)

price_levels = pd.concat(
    [pe_wc_prices.rename("P/E"), ev_wc_prices.rename("EV/EBITDA")],
    axis=1,
)
multiple_levels = pd.concat(
    [pe_wc_levels.rename("P/E"), ev_wc_levels.rename("EV/EBITDA")],
    axis=1,
)

ev_quantiles = valuation_quantiles(ev_series)
pe_quantiles = valuation_quantiles(pe_series)
ev_quantile_prices = prices_from_multiples(
    ev_quantiles, "EV/EBITDA", ebitda, net_debt, eps, shares_outstanding
)
pe_quantile_prices = prices_from_multiples(
    pe_quantiles, "P/E", ebitda, net_debt, eps, shares_outstanding
)

quantile_multiple_table = pd.concat(
    [pe_quantiles.rename("P/E"), ev_quantiles.rename("EV/EBITDA")],
    axis=1,
)
quantile_price_table = pd.concat(
    [
        pe_quantile_prices.rename("P/E"),
        ev_quantile_prices.rename("EV/EBITDA"),
    ],
    axis=1,
)

ev_frequencies = historical_frequency(ev_series, current_ev_ebitda)
pe_frequencies = historical_frequency(pe_series, current_pe)
frequency_table = pd.concat(
    [pe_frequencies.rename("P/E"), ev_frequencies.rename("EV/EBITDA")],
    axis=1,
)

ev_histogram = histogram_table(ev_series, bins=15)
pe_histogram = histogram_table(pe_series, bins=15)
ev_risk_reward = calculate_risk_reward(
    price, ev_wc_prices.loc["WC"], ev_wc_prices.loc["Sell"]
)
pe_risk_reward = calculate_risk_reward(
    price, pe_wc_prices.loc["WC"], pe_wc_prices.loc["Sell"]
)
assert (
    ev_histogram["Number of Observations"].sum()
    == len(ev_series)
)

assert (
    pe_histogram["Number of Observations"].sum()
    == len(pe_series)
)

# %% [markdown]
# ## Step 4: Results

# %%
snapshot_summary = pd.Series(
    {
        f"Share Price as of {price_date.date()}": price,
        f"P/E as of {price_date.date()}": current_pe,
        f"EV/EBITDA as of {price_date.date()}": current_ev_ebitda,
        "EPS (TTM)": eps,
    },
    name="Value",
)

def format_ratio(value):
    if np.isinf(value):
        return "inf"
    if pd.isna(value):
        return "n/a"
    return f"{value:.2f}"


print("1. Point-in-Time Inputs")
with pd.option_context("display.float_format", "{:,.2f}".format):
    display(snapshot_summary.to_frame())

print("2. Prices - WC / Buy / FV / Sell")
with pd.option_context("display.float_format", lambda value: f"${value:,.2f}"):
    display(price_levels)

print("3. Figures - WC / Buy / FV / Sell")
with pd.option_context("display.float_format", "{:.2f}".format):
    display(multiple_levels)

print("4. Historical Multiple Quantiles")
with pd.option_context("display.float_format", "{:.2f}".format):
    display(quantile_multiple_table)

print("5. Historical Quantile-Implied Share Prices")
with pd.option_context("display.float_format", lambda value: f"${value:,.2f}"):
    display(quantile_price_table)

print("6. Direct Empirical Historical Frequencies")
with pd.option_context("display.float_format", "{:.2%}".format):
    display(frequency_table)

print("7. Full Histogram Table for EV/EBITDA")
with pd.option_context("display.float_format", "{:,.2f}".format):
    display(ev_histogram)

print("8. Full Histogram Table for P/E")
with pd.option_context("display.float_format", "{:,.2f}".format):
    display(pe_histogram)

print("9. EV/EBITDA Risk-Reward Ratio")
print("\n- EV/EBITDA Risk-Reward Ratio -\n")
print(f"EV/EBITDA as of {price_date.date()}: {current_ev_ebitda:.2f}")
print(f"Risk-Reward Ratio: {format_ratio(ev_risk_reward['Risk/Reward Ratio'])} : 1")
print(f"Chance: ${ev_risk_reward['Chance']:,.2f}")
print(f"Risk: ${ev_risk_reward['Risk']:,.2f}")

print("\n10. P/E Risk-Reward Ratio")
print("\n- P/E Risk-Reward Ratio -\n")
print(f"P/E as of {price_date.date()}: {current_pe:.2f}")
print(f"Risk-Reward Ratio: {format_ratio(pe_risk_reward['Risk/Reward Ratio'])} : 1")
print(f"Chance: ${pe_risk_reward['Chance']:,.2f}")
print(f"Risk: ${pe_risk_reward['Risk']:,.2f}")

assert np.isclose(ev_frequencies.sum(), 1.0)
assert np.isclose(pe_frequencies.sum(), 1.0)
# Out:
# 1. Point-in-Time Inputs
#                               Value
# Share Price as of 2025-12-26 487.71
# P/E as of 2025-12-26          34.70
# EV/EBITDA as of 2025-12-26    20.73
# EPS (TTM)                     14.06
# 2. Prices - WC / Buy / FV / Sell
#          P/E  EV/EBITDA
# WC   $168.67    $142.14
# Buy  $188.67    $144.53
# FV   $343.59    $310.08
# Sell $498.52    $475.63
# 3. Figures - WC / Buy / FV / Sell
#        P/E  EV/EBITDA
# WC   12.00       7.00
# Buy  13.42       7.11
# FV   24.45      15.03
# Sell 35.47      22.95
# 4. Historical Multiple Quantiles
#                      P/E  EV/EBITDA
# Q10 Lower Quantile 11.54       6.41
# Q25                15.46       8.29
# Q50 Median         24.93      13.55
# Q75                34.00      20.11
# Q90 Upper Quantile 37.14      23.89
# 5. Historical Quantile-Implied Share Prices
#                        P/E  EV/EBITDA
# Q10 Lower Quantile $162.23    $129.86
# Q25                $217.27    $169.06
# ...

# %% [markdown]
# ## 11. Limitations
#
# - Historical frequencies are descriptive and are not forecast probabilities.
# - WC/Buy/FV/Sell levels summarize historical multiple distributions; they are not price forecasts.
# - EV/EBITDA uses FY2025 EBITDA while the current multiple is observed closer to 2025-12-26.
# - Net debt uses TotalDebt and CashAndCashEquivalents from the 2025-09-30 quarterly snapshot.
# - The different financial-statement and market-data periods are shown explicitly.
# - Historical valuation levels need not recur as fundamentals and market regimes change.
